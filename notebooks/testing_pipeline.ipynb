# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

# %%
from run_pipeline import main
import run_pipeline

# %%
main()
# Out:
# Win Rate: 0.6315005215318135
# /Users/rowanzinn/github_projects/sales-pipeline-analytics/src/data_cleaning.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pipeline["account"] = pipeline["account"].fillna("Unknown")
# /Users/rowanzinn/github_projects/sales-pipeline-analytics/src/data_cleaning.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pipeline["is_closed"] = pipeline["deal_stage"].isin(["Won", "Lost"])
# ...
